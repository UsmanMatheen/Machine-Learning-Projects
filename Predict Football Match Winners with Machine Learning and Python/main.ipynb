# %%
import pandas as pd

# %%
matches =  pd.read_csv("matches.csv", index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 0  2024-08-17  12:30  Premier League  Matchweek 1  Sat  Away      W  2.0  0.0
# 1  2024-08-25  16:30  Premier League  Matchweek 2  Sun  Home      W  2.0  0.0
# 2  2024-09-01  16:00  Premier League  Matchweek 3  Sun  Away      W  3.0  0.0
# 3  2024-09-14  15:00  Premier League  Matchweek 4  Sat  Home      L  0.0  1.0
# 4  2024-09-21  15:00  Premier League  Matchweek 5  Sat  Home      W  3.0  0.0
#
#           opponent  ...  match report  notes    sh   sot  dist   fk pk pkatt  \
# 0     Ipswich Town  ...  Match Report    NaN  18.0   5.0  14.8  0.0  0     0
# 1        Brentford  ...  Match Report    NaN  19.0   8.0  13.6  1.0  0     0
# 2   Manchester Utd  ...  Match Report    NaN  11.0   3.0  13.4  0.0  0     0
# 3  Nott'ham Forest  ...  Match Report    NaN  14.0   5.0  14.9  0.0  0     0
# 4      Bournemouth  ...  Match Report    NaN  19.0  12.0  16.6  0.0  0     0
#
#   season       team
# 0   2024  Liverpool
# 1   2024  Liverpool
# 2   2024  Liverpool
# 3   2024  Liverpool
# 4   2024  Liverpool
#
# [5 rows x 28 columns]

# %%
matches.shape
# Out:
# (1918, 28)

# %%
38*20*3
# Out:
# 2280

# %%
matches["team"].value_counts()
# Out:
# team
# Manchester United           96
# Wolverhampton Wanderers     96
# Nottingham Forest           96
# Chelsea                     96
# Newcastle United            96
# Manchester City             96
# Bournemouth                 96
# Aston Villa                 96
# Fulham                      96
# Brighton and Hove Albion    96
# Brentford                   96
# Tottenham Hotspur           96
# Arsenal                     96
# West Ham United             96
# Crystal Palace              96
# Liverpool                   95
# Everton                     95
# Leicester City              58
# Southampton                 58
# Luton Town                  38
# Burnley                     38
# Sheffield United            38
# Leeds United                38
# Ipswich Town                20
# Name: count, dtype: int64

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     60
# Matchweek 11    60
# Matchweek 19    60
# Matchweek 18    60
# Matchweek 17    60
# Matchweek 16    60
# Matchweek 14    60
# Matchweek 13    60
# Matchweek 12    60
# Matchweek 10    60
# Matchweek 2     60
# Matchweek 9     60
# Matchweek 8     60
# Matchweek 7     60
# Matchweek 6     60
# Matchweek 5     60
# Matchweek 4     60
# Matchweek 3     60
# Matchweek 20    60
# Matchweek 15    58
# Matchweek 21    40
# Matchweek 22    40
# Matchweek 34    40
# Matchweek 37    40
# Matchweek 36    40
# Matchweek 35    40
# Matchweek 29    40
# Matchweek 33    40
# Matchweek 32    40
# Matchweek 31    40
# Matchweek 30    40
# Matchweek 28    40
# Matchweek 27    40
# Matchweek 26    40
# Matchweek 25    40
# Matchweek 24    40
# Matchweek 23    40
# Matchweek 38    40
# Name: count, dtype: int64

# %%
matches.dtypes
# Out:
# date              object
# time              object
# comp              object
# round             object
# day               object
# venue             object
# result            object
# gf               float64
# ga               float64
# opponent          object
# xg               float64
# xga              float64
# poss             float64
# attendance       float64
# captain           object
# formation         object
# opp formation     object
# referee           object
# match report      object
# notes            float64
# sh               float64
# sot              float64
# dist             float64
# fk               float64
# pk                 int64
# pkatt              int64
# season             int64
# team              object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"], errors="coerce")

# %%
matches.dtypes
# Out:
# date             datetime64[ns]
# time                     object
# comp                     object
# round                    object
# day                      object
# venue                    object
# result                   object
# gf                      float64
# ga                      float64
# opponent                 object
# xg                      float64
# xga                     float64
# poss                    float64
# attendance              float64
# captain                  object
# formation                object
# opp formation            object
# referee                  object
# match report             object
# notes                   float64
# sh                      float64
# sot                     float64
# dist                    float64
# fk                      float64
# pk                        int64
# pkatt                     int64
# season                    int64
# team                     object
# venue_code                 int8
# opp_code                   int8
# hour                      int32
# day_code                  int32
# target                    int32
# dtype: object

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches["target"] =  (matches["result"] =="W").astype("int")

# %%
matches
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W  2.0
# 1    2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W  2.0
# 2    2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W  3.0
# 3    2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L  0.0
# 4    2024-09-21  15:00  Premier League   Matchweek 5  Sat  Home      W  3.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 1913 2023-04-30  14:00  Premier League  Matchweek 34  Sun  Away      L  1.0
# 1914 2023-05-08  20:00  Premier League  Matchweek 35  Mon  Away      L  3.0
# 1915 2023-05-13  15:00  Premier League  Matchweek 36  Sat  Home      L  0.0
# 1916 2023-05-21  14:00  Premier League  Matchweek 37  Sun  Away      L  1.0
# 1917 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Home      D  4.0
#
#        ga         opponent  ...   fk  pk  pkatt  season         team  \
# 0     0.0     Ipswich Town  ...  0.0   0      0    2024    Liverpool
# 1     0.0        Brentford  ...  1.0   0      0    2024    Liverpool
# 2     0.0   Manchester Utd  ...  0.0   0      0    2024    Liverpool
# 3     1.0  Nott'ham Forest  ...  0.0   0      0    2024    Liverpool
# 4     0.0      Bournemouth  ...  0.0   0      0    2024    Liverpool
# ...   ...              ...  ...  ...  ..    ...     ...          ...
# 1913  3.0    Newcastle Utd  ...  0.0   0      0    2022  Southampton
# 1914  4.0  Nott'ham Forest  ...  0.0   1      1    2022  Southampton
# 1915  2.0           Fulham  ...  0.0   0      0    2022  Southampton
# 1916  3.0         Brighton  ...  1.0   0      0    2022  Southampton
# 1917  4.0        Liverpool  ...  1.0   0      0    2022  Southampton
#
#      venue_code opp_code hour day_code  target
# 0             0       10   12        5       1
# 1             1        3   16        6       1
# 2             0       16   16        6       1
# 3             1       18   15        5       0
# 4             1        2   15        5       1
# ...         ...      ...  ...      ...     ...
# 1913          0       17   14        6       0
# 1914          0       18   20        0       0
# 1915          1        9   15        5       0
# 1916          0        4   14        6       0
# 1917          1       13   16        6       0
#
# [1918 rows x 33 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf= RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < "2024-01-01"]

# %%
test = matches[matches["date"] > "24-01-01"]

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
matches["date"] = pd.to_datetime(matches["date"], errors="coerce")

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc= accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.6866527632950991

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted    0    1
# actual
# 0          947  237
# 1          364  370

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# 0.6095551894563427

# %%
grouped_matches= matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City")

# %%
group
# Out:
#            date   time            comp         round  day venue result   gf  \
# 99   2024-08-18  16:30  Premier League   Matchweek 1  Sun  Away      W  2.0
# 100  2024-08-24  15:00  Premier League   Matchweek 2  Sat  Home      W  4.0
# 101  2024-08-31  17:30  Premier League   Matchweek 3  Sat  Away      W  3.0
# 102  2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      W  2.0
# 103  2024-09-22  16:30  Premier League   Matchweek 5  Sun  Home      D  2.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 1191 2023-05-06  15:00  Premier League  Matchweek 35  Sat  Home      W  2.0
# 1192 2023-05-14  14:00  Premier League  Matchweek 36  Sun  Away      W  3.0
# 1193 2023-05-21  16:00  Premier League  Matchweek 37  Sun  Home      W  1.0
# 1194 2023-05-24  20:00  Premier League  Matchweek 32  Wed  Away      D  1.0
# 1195 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      L  0.0
#
#        ga      opponent  ...   fk  pk  pkatt  season             team  \
# 99    0.0       Chelsea  ...  0.0   0      0    2024  Manchester City
# 100   1.0  Ipswich Town  ...  1.0   1      1    2024  Manchester City
# 101   1.0      West Ham  ...  1.0   0      0    2024  Manchester City
# 102   1.0     Brentford  ...  0.0   0      0    2024  Manchester City
# 103   2.0       Arsenal  ...  1.0   0      0    2024  Manchester City
# ...   ...           ...  ...  ...  ..    ...     ...              ...
# 1191  1.0  Leeds United  ...  2.0   0      1    2022  Manchester City
# 1192  0.0       Everton  ...  2.0   0      0    2022  Manchester City
# 1193  0.0       Chelsea  ...  0.0   0      0    2022  Manchester City
# 1194  1.0      Brighton  ...  0.0   0      0    2022  Manchester City
# 1195  1.0     Brentford  ...  0.0   0      0    2022  Manchester City
#
#      venue_code opp_code hour day_code  target
# 99            0        6   16        6       1
# 100           1       10   15        5       1
# 101           0       22   17        5       1
# 102           1        3   15        5       1
# 103           1        0   16        6       0
# ...         ...      ...  ...      ...     ...
# 1191          1       11   15        5       1
# 1192          0        8   14        6       1
# 1193          1        6   16        6       1
# 1194          0        4   20        2       0
# 1195          0        3   16        6       0
#
# [96 rows x 33 columns]

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group =  group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#            date   time            comp         round  day venue result   gf  \
# 1161 2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W  4.0
# 1162 2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  6.0
# 1163 2022-09-03  17:30  Premier League   Matchweek 6  Sat  Away      D  1.0
# 1164 2022-09-17  12:30  Premier League   Matchweek 8  Sat  Away      W  3.0
# 1165 2022-10-02  14:00  Premier League   Matchweek 9  Sun  Home      W  6.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 114  2024-12-15  16:30  Premier League  Matchweek 16  Sun  Home      L  1.0
# 115  2024-12-21  12:30  Premier League  Matchweek 17  Sat  Away      L  1.0
# 116  2024-12-26  12:30  Premier League  Matchweek 18  Thu  Home      D  1.0
# 117  2024-12-29  14:30  Premier League  Matchweek 19  Sun  Away      W  2.0
# 118  2025-01-04  15:00  Premier League  Matchweek 20  Sat  Home      W  4.0
#
#        ga         opponent  ...  day_code  target  gf_rolling  ga_rolling  \
#
rows x 41 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2022-08-27  17:30  Premier League   Matchweek 4  Sat  Home      W  2.0
# 1    2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  2.0
# 2    2022-09-04  16:30  Premier League   Matchweek 6  Sun  Away      L  1.0
# 3    2022-09-18  12:00  Premier League   Matchweek 8  Sun  Away      W  3.0
# 4    2022-10-01  12:30  Premier League   Matchweek 9  Sat  Home      W  3.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 1841 2024-12-14  15:00  Premier League  Matchweek 16  Sat  Home      L  1.0
# 1842 2024-12-22  14:00  Premier League  Matchweek 17  Sun  Away      W  3.0
# 1843 2024-12-26  17:30  Premier League  Matchweek 18  Thu  Home      W  2.0
# 1844 2024-12-29  15:00  Premier League  Matchweek 19  Sun  Away      D  2.0
# 1845 2025-01-06  20:00  Premier League  Matchweek 20  Mon  Home      L  0.0
#
#        ga         opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 0     1.0           Fulham  ...         5       1    3.000000    0.666667
# 1     1.0      Aston Villa  ...         2       1    3.000000    1.000000
# 2     3.0   Manchester Utd  ...         6       0    2.333333    0.666667
# 3     0.0        Brentford  ...         6       1    1.666667    1.666667
# 4     1.0        Tottenham  ...         5       1    2.000000    1.333333
# ...   ...              ...  ...       ...     ...         ...         ...
# 1841  2.0     Ipswich Town  ...         5       0    1.000000    3.333333
# 1842  0.0   Leicester City  ...         6       1    0.666667    2.666667
# 1843  0.0   Manchester Utd  ...         3       1    1.666667    1.333333
# 1844  2.0        Tottenham  ...         6       0    2.000000    0.666667
# 1845  3.0  Nott'ham Forest  ...         0       0    2.333333    0.666667
#
#      sh_rolling sot_rolling dist_rolling fk_rolling pk_rolling  pkatt_rolling
# 0     14.333333    5.000000    14.133333   0.333333        0.0            0.0
# 1     18.333333    7.000000    14.433333   0.333333        0.0            0.0
# 2     19.333333    7.333333    15.533333   0.666667        0.0            0.0
# 3     20.000000    6.333333    16.800000   1.000000        0.0            0.0
# 4     17.000000    6.000000    17.700000   0.666667        0.0            0.0
# ...         ...         ...          ...        ...        ...            ...
# 1841  11.666667    3.333333    19.500000   0.333333        0.0            0.0
# 1842  13.666667    4.333333    19.000000   0.000000        0.0            0.0
# 1843  14.333333    5.000000    16.966667   0.333333        0.0            0.0
# 1844  10.333333    4.666667    19.033333   0.666667        0.0            0.0
# 1845   8.666667    3.666667    19.566667   1.000000        0.0            0.0
#
# [1846 rows x 41 columns]

# %%
# Retraining the machine learning model

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < "2024-01-01"]
    test = data[data["date"] > "24-01-01"]
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index = test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.7987220447284346

# %%
combined
# Out:
#       actual  predicted
# 0          1          1
# 1          1          1
# 2          0          0
# 3          1          1
# 4          1          1
# ...      ...        ...
# 1841       0          0
# 1842       1          0
# 1843       1          1
# 1844       0          0
# 1845       0          1
#
# [1846 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index= True, right_index=True)

# %%
combined
# Out:
#       actual  predicted       date                     team         opponent  \
# 0          1          1 2022-08-27                  Arsenal           Fulham
# 1          1          1 2022-08-31                  Arsenal      Aston Villa
# 2          0          0 2022-09-04                  Arsenal   Manchester Utd
# 3          1          1 2022-09-18                  Arsenal        Brentford
# 4          1          1 2022-10-01                  Arsenal        Tottenham
# ...      ...        ...        ...                      ...              ...
# 1841       0          0 2024-12-14  Wolverhampton Wanderers     Ipswich Town
# 1842       1          0 2024-12-22  Wolverhampton Wanderers   Leicester City
# 1843       1          1 2024-12-26  Wolverhampton Wanderers   Manchester Utd
# 1844       0          0 2024-12-29  Wolverhampton Wanderers        Tottenham
# 1845       0          1 2025-01-06  Wolverhampton Wanderers  Nott'ham Forest
#
#      result
# 0         W
# 1         W
# 2         L
# 3         W
# 4         W
# ...     ...
# 1841      L
# 1842      W
# 1843      W
# 1844      D
# 1845      L
#
# [1846 rows x 6 columns]

# %%
### Combining home and away predictions

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key
map_values = {
    "Brighton and Hove Albion": "Brighton",
    "Manchester United": "Manchester Utd",
    "Newcastle United": "Newcastle Utd",
    "Tottenham Hotspur": "Tottenham",
    "West Ham United": "West Ham",
    "Wolverhampton Wanderers": "Wolves"
    
}
mapping = MissingDict(**map_values)

# %%
mapping["Manchester United"]
# Out:
# 'Manchester Utd'

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
combined
# Out:
#       actual  predicted       date                     team         opponent  \
# 0          1          1 2022-08-27                  Arsenal           Fulham
# 1          1          1 2022-08-31                  Arsenal      Aston Villa
# 2          0          0 2022-09-04                  Arsenal   Manchester Utd
# 3          1          1 2022-09-18                  Arsenal        Brentford
# 4          1          1 2022-10-01                  Arsenal        Tottenham
# ...      ...        ...        ...                      ...              ...
# 1841       0          0 2024-12-14  Wolverhampton Wanderers     Ipswich Town
# 1842       1          0 2024-12-22  Wolverhampton Wanderers   Leicester City
# 1843       1          1 2024-12-26  Wolverhampton Wanderers   Manchester Utd
# 1844       0          0 2024-12-29  Wolverhampton Wanderers        Tottenham
# 1845       0          1 2025-01-06  Wolverhampton Wanderers  Nott'ham Forest
#
#      result new_team
# 0         W  Arsenal
# 1         W  Arsenal
# 2         L  Arsenal
# 3         W  Arsenal
# 4         W  Arsenal
# ...     ...      ...
# 1841      L   Wolves
# 1842      W   Wolves
# 1843      W   Wolves
# 1844      D   Wolves
# 1845      L   Wolves
#
# [1846 rows x 7 columns]

# %%
merged = combined.merge(combined, left_on=["date","new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#       actual_x  predicted_x       date                   team_x  \
# 0            1            1 2022-08-27                  Arsenal
# 1            1            1 2022-08-31                  Arsenal
# 2            0            0 2022-09-04                  Arsenal
# 3            1            1 2022-09-18                  Arsenal
# 4            1            1 2022-10-01                  Arsenal
# ...        ...          ...        ...                      ...
# 1702         0            0 2024-12-14  Wolverhampton Wanderers
# 1703         1            0 2024-12-22  Wolverhampton Wanderers
# 1704         1            1 2024-12-26  Wolverhampton Wanderers
# 1705         0            0 2024-12-29  Wolverhampton Wanderers
# 1706         0            1 2025-01-06  Wolverhampton Wanderers
#
#            opponent_x result_x new_team_x  actual_y  predicted_y  \
# 0              Fulham        W    Arsenal         0            0
# 1         Aston Villa        W    Arsenal         0            0
# 2      Manchester Utd        L    Arsenal         1            0
# 3           Brentford        W    Arsenal         0            0
# 4           Tottenham        W    Arsenal         0            0
# ...               ...      ...        ...       ...          ...
# 1702     Ipswich Town        L     Wolves         1            0
# 1703   Leicester City        W     Wolves         0            0
# 1704   Manchester Utd        W     Wolves         0            0
# 1705        Tottenham        D     Wolves         0            1
# 1706  Nott'ham Forest        L     Wolves         1            0
#
#                  team_y opponent_y result_y         new_team_y
# 0                Fulham    Arsenal        L             Fulham
# 1           Aston Villa    Arsenal        L        Aston Villa
# 2     Manchester United    Arsenal        W     Manchester Utd
# 3             Brentford    Arsenal        L          Brentford
# 4     Tottenham Hotspur    Arsenal        L          Tottenham
# ...                 ...        ...      ...                ...
# 1702       Ipswich Town     Wolves        W       Ipswich Town
# 1703     Leicester City     Wolves        L     Leicester City
# 1704  Manchester United     Wolves        L     Manchester Utd
# 1705  Tottenham Hotspur     Wolves        D          Tottenham
# 1706  Nottingham Forest     Wolves        W  Nottingham Forest
#
# [1707 rows x 13 columns]

# %%
merged[(merged["predicted_x"]==1) & (merged["predicted_y"]==0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    462
# 0     97
# Name: count, dtype: int64

# %%
precision
# Out:
# 0.7987220447284346
